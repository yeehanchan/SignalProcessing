# %%
# %pylab inline
import rlcompleter, readline
readline.parse_and_bind('tab: complete')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = np.genfromtxt("train.csv",delimiter=',',dtype='str')

# %%
train = np.asarray(data[1:501,1:],dtype='int')
label = np.asarray(data[1:501,0],dtype='int')

# %%
print train.shape
print label
# Out:
# (500, 784)
# [1 0 1 4 0 0 7 3 5 3 8 9 1 3 3 1 2 0 7 5 8 6 2 0 2 3 6 9 9 7 8 9 4 9 2 1 3
#  1 1 4 9 1 4 4 2 6 3 7 7 4 7 5 1 9 0 2 2 3 9 1 1 1 5 0 6 3 4 8 1 0 3 9 6 2
#  6 4 7 1 4 1 5 4 8 9 2 9 9 8 9 6 3 6 4 6 2 9 1 2 0 5 9 2 7 7 2 8 8 5 0 6 0
#  0 2 9 0 4 7 7 1 5 7 9 4 6 1 5 7 6 5 0 4 8 7 6 1 8 7 3 7 3 1 0 3 4 5 4 0 5
#  4 0 3 5 1 0 8 3 7 0 9 6 6 9 5 4 6 9 3 5 4 2 4 8 7 7 5 8 8 8 2 6 9 3 1 0 4
#  1 5 9 0 6 2 1 3 0 6 0 0 8 3 2 0 0 6 0 0 4 7 2 7 1 9 9 3 9 8 4 6 6 5 3 8 1
#  8 7 1 3 7 6 3 6 3 6 3 2 3 2 2 7 9 2 3 2 7 5 5 8 8 2 0 1 4 0 6 3 7 1 1 1 4
#  7 0 2 9 2 0 5 6 0 8 9 6 2 0 0 7 2 0 4 2 0 9 1 6 9 3 0 0 2 0 6 8 4 0 7 2 1
#  9 5 2 4 8 5 2 9 7 9 2 9 7 4 9 3 2 7 3 6 3 6 8 8 3 7 0 9 2 7 9 0 5 4 5 8 4
#  3 3 1 7 8 9 7 6 2 1 7 0 5 6 5 2 9 5 4 6 2 2 2 9 0 7 7 2 2 6 3 4 2 0 5 9 6
#  2 1 9 0 6 0 4 8 4 3 1 5 4 2 9 5 7 3 1 5 4 5 3 7 3 8 6 2 4 6 1 1 4 0 0 5 8
#  6 7 4 2 8 0 2 5 4 8 3 0 6 4 8 6 4 1 8 1 5 4 9 4 3 2 0 5 0 7 9 2 9 8 9 6 5
# ...

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
reduced = pca.fit_transform(train)
transformed = pca.inverse_transform(reduced)

# %%
plt.scatter(reduced[:,0],reduced[:,1])
np.savetxt("PCA_reduction.txt",reduced)

# %%
digit_0 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 0])
digit_1 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 1])
digit_2 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 2])
digit_3 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 3])
digit_4 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 4])
digit_5 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 5])
digit_6 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 6])
digit_7 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 7])
digit_8 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 8])
digit_9 = np.asarray([reduced[i] for i in range(len(label)) if label[i] == 9])

# %%
#plt.scatter(reduced[:,0],reduced[:,1])
plt.scatter(digit_0[:,0],digit_0[:,1],c='r')
#plt.annotate('0', xy=(digit_0[0][0],digit_0[0][1]),size =50)
plt.scatter(digit_1[:,0],digit_1[:,1],c='g')
#plt.annotate('1', xy=(digit_1[0][0],digit_1[0][1]),size =50)
plt.scatter(digit_2[:,0],digit_2[:,1],c='w')
plt.scatter(digit_3[:,0],digit_3[:,1],c='b')
#plt.annotate('3', xy=(digit_3[15][0],digit_3[15][1]),size =50)
plt.scatter(digit_4[:,0],digit_4[:,1],c='magenta')
#plt.annotate('4', xy=(digit_4[6][0],digit_4[6][1]),size =50)
plt.scatter(digit_5[:,0],digit_5[:,1],c='brown')
plt.scatter(digit_6[:,0],digit_6[:,1],c='cyan')
#plt.annotate('6', xy=(digit_6[4][0],digit_6[4][1]),size =50)
plt.scatter(digit_7[:,0],digit_7[:,1],c='black')
plt.scatter(digit_8[:,0],digit_8[:,1],c='yellow')
plt.scatter(digit_9[:,0],digit_9[:,1],c='grey')

# %%
#plt.scatter(reduced[:,0],reduced[:,1])
plt.scatter(digit_0[:,0],digit_0[:,1],c='r')
plt.annotate('0', xy=(digit_0[0][0],digit_0[0][1]),size =50)
plt.scatter(digit_1[:,0],digit_1[:,1],c='g')
plt.annotate('1', xy=(digit_1[0][0],digit_1[0][1]),size =50)
#plt.scatter(digit_2[:,0],digit_2[:,1],c='w')
plt.scatter(digit_3[:,0],digit_3[:,1],c='b')
plt.annotate('3', xy=(digit_3[15][0],digit_3[15][1]),size =50)
plt.scatter(digit_4[:,0],digit_4[:,1],c='magenta')
plt.annotate('4', xy=(digit_4[6][0],digit_4[6][1]),size =50)
#plt.scatter(digit_5[:,0],digit_5[:,1],c='brown')
plt.scatter(digit_6[:,0],digit_6[:,1],c='cyan')
plt.annotate('6', xy=(digit_6[4][0],digit_6[4][1]),size =50)
#plt.scatter(digit_7[:,0],digit_7[:,1],c='black')
#plt.scatter(digit_8[:,0],digit_8[:,1],c='yellow')
#plt.scatter(digit_9[:,0],digit_9[:,1],c='grey')

# %%
from sklearn.manifold import Isomap
isomap = Isomap(n_components=2)
ireduced = isomap.fit_transform(train)

# %%
plt.scatter(ireduced[:,0],ireduced[:,1])
np.savetxt("Isomap_reduction.txt",ireduced)

# %%
idigit_0 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 0])
idigit_1 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 1])
idigit_2 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 2])
idigit_3 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 3])
idigit_4 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 4])
idigit_5 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 5])
idigit_6 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 6])
idigit_7 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 7])
idigit_8 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 8])
idigit_9 = np.asarray([ireduced[i] for i in range(len(label)) if label[i] == 9])

# %%
#plt.scatter(reduced[:,0],reduced[:,1])
plt.scatter(idigit_0[:,0],idigit_0[:,1],c='r')
#plt.annotate('0', xy=(idigit_0[0][0],idigit_0[0][1]),size =50)
plt.scatter(idigit_1[:,0],idigit_1[:,1],c='g')
#plt.annotate('1', xy=(idigit_1[0][0],idigit_1[0][1]),size =50)
plt.scatter(idigit_2[:,0],idigit_2[:,1],c='w')
plt.scatter(idigit_3[:,0],idigit_3[:,1],c='b')
#plt.annotate('3', xy=(idigit_3[15][0],idigit_3[15][1]),size =50)
plt.scatter(idigit_4[:,0],idigit_4[:,1],c='magenta')
#plt.annotate('4', xy=(idigit_4[6][0],idigit_4[6][1]),size =50)
plt.scatter(idigit_5[:,0],idigit_5[:,1],c='brown')
plt.scatter(idigit_6[:,0],idigit_6[:,1],c='cyan')
#plt.annotate('6', xy=(idigit_6[4][0],idigit_6[4][1]),size =50)
plt.scatter(idigit_7[:,0],idigit_7[:,1],c='black')
plt.scatter(idigit_8[:,0],idigit_8[:,1],c='yellow')
plt.scatter(idigit_9[:,0],idigit_9[:,1],c='grey')
#plt.annotate('9', xy=(idigit_9[17][0],idigit_9[17][1]),size =50)

# %%
#plt.scatter(ireduced[:,0],ireduced[:,1])
plt.scatter(idigit_0[:,0],idigit_0[:,1],c='r')
plt.annotate('0', xy=(idigit_0[0][0],idigit_0[0][1]),size =50)
plt.scatter(idigit_1[:,0],idigit_1[:,1],c='g')
plt.annotate('1', xy=(idigit_1[0][0],idigit_1[0][1]),size =50)
#plt.scatter(idigit_2[:,0],idigit_2[:,1],c='w')
plt.scatter(idigit_3[:,0],idigit_3[:,1],c='b')
plt.annotate('3', xy=(idigit_3[15][0],idigit_3[15][1]),size =50)
#plt.scatter(idigit_4[:,0],idigit_4[:,1],c='magenta')
#plt.annotate('4', xy=(idigit_4[6][0],idigit_4[6][1]),size =50)
#plt.scatter(idigit_5[:,0],idigit_5[:,1],c='brown')
plt.scatter(idigit_6[:,0],idigit_6[:,1],c='cyan')
plt.annotate('6', xy=(idigit_6[4][0],idigit_6[4][1]),size =50)
#plt.scatter(idigit_7[:,0],idigit_7[:,1],c='black')
#plt.scatter(idigit_8[:,0],idigit_8[:,1],c='yellow')
plt.scatter(idigit_9[:,0],idigit_9[:,1],c='grey')
plt.annotate('9', xy=(idigit_9[17][0],idigit_9[17][1]),size =50)

# %%
from sklearn.manifold import LocallyLinearEmbedding
lle = LocallyLinearEmbedding(n_components = 2)
lreduced = lle.fit_transform(train)

# %%
plt.scatter(lreduced[:,0],lreduced[:,1])
np.savetxt("LLE_reduction.txt",lreduced)

# %%
ldigit_0 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 0])
ldigit_1 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 1])
ldigit_2 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 2])
ldigit_3 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 3])
ldigit_4 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 4])
ldigit_5 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 5])
ldigit_6 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 6])
ldigit_7 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 7])
ldigit_8 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 8])
ldigit_9 = np.asarray([lreduced[i] for i in range(len(label)) if label[i] == 9])

# %%
#plt.scatter(reduced[:,0],reduced[:,1])
plt.scatter(ldigit_0[:,0],ldigit_0[:,1],c='r')
#plt.annotate('0', xy=(idigit_0[0][0],idigit_0[0][1]),size =50)
plt.scatter(ldigit_1[:,0],ldigit_1[:,1],c='g')
#plt.annotate('1', xy=(idigit_1[0][0],idigit_1[0][1]),size =50)
plt.scatter(ldigit_2[:,0],ldigit_2[:,1],c='w')
plt.scatter(ldigit_3[:,0],ldigit_3[:,1],c='b')
#plt.annotate('3', xy=(idigit_3[15][0],idigit_3[15][1]),size =50)
plt.scatter(ldigit_4[:,0],ldigit_4[:,1],c='magenta')
#plt.annotate('4', xy=(idigit_4[6][0],idigit_4[6][1]),size =50)
plt.scatter(ldigit_5[:,0],ldigit_5[:,1],c='brown')
plt.scatter(ldigit_6[:,0],ldigit_6[:,1],c='cyan')
#plt.annotate('6', xy=(idigit_6[4][0],idigit_6[4][1]),size =50)
plt.scatter(ldigit_7[:,0],ldigit_7[:,1],c='black')
plt.scatter(ldigit_8[:,0],ldigit_8[:,1],c='yellow')
plt.scatter(ldigit_9[:,0],ldigit_9[:,1],c='grey')
#plt.annotate('9', xy=(idigit_9[17][0],idigit_9[17][1]),size =50)

# %%
from sklearn.decomposition import KernelPCA
kpca = KernelPCA(n_components = 2)
kreduced = kpca.fit_transform(train)

# %%
plt.scatter(kreduced[:,0],kreduced[:,1])

# %%
np.savetxt("train_500.txt",train)
np.savetxt("label_500.txt",label)
